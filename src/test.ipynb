# %%
from logic.game import RockPaperScissors



        

if __name__ == "__main__":
    game = RockPaperScissors()
    game.play()
# Out:
# Computer chose: paper
# Computer wins!
# Goodbye!

# %%
class ScoreBoard:
    def __init__(self):
        self.user_score = 0
        self.computer_score = 0

    def update_score(self, result: str):
        if result == "user":
            self.user_score += 1
        elif result == "computer":
            self.computer_score += 1

    def display_score(self):
        print(f"User Score: {self.user_score}, Computer Score: {self.computer_score}")

# %%
class Scoreboard:
    def __init__(self):
        self.user_score = 0
        self.computer_score = 0

    def update_score(self, winner: str):
        if winner == "user":
            self.user_score += 1
        elif winner == "computer":
            self.computer_score += 1

    def display_score(self):
        print(f"User Score: {self.user_score}, Computer Score: {self.computer_score}")

# %% [markdown]
# 1- get user choice
# 2- get computer choice
# 3- compare choices
# 4- declare winner
